# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
#https://www.kaggle.com/clmentbisaillon/classifying-fake-news-with-bert

# %%
df = pd.read_csv(r'C:\Users\lilie\OneDrive\Bureau\ironHack\dataset\fake_real_final.csv')

# %%
from sklearn.utils import shuffle
df = shuffle(df).reset_index(drop=True)
df.head()
# Out:
#                                                title  \
# 0  MSM Fake News: How Washington Post Sexed-up it...
# 1  Germany extends passport controls on Austrian ...
# 2  After tragic shooting, Charleston church reope...
# 3  Kremlin says Washington must prove hacking acc...
# 4  FAMILY OF S.C. SHOOTING VICTIM HAS A MESSAGE F...
#
#                                                 text  label_REAL  \
# 0  This is a story about how once trusted mainstr...           0
# 1  BERLIN (Reuters) - Germany has extended tempor...           1
# 2  CHARLESTON, S.C. — Emanuel AME Church swung op...           1
# 3  TOKYO (Reuters) - The Kremlin said on Friday t...           1
# 4  Poor little Al if he s not race baiting, he s ...           0
#
#         subject         date
# 0   Middle-east   09-26-2017
# 1     worldnews  10-12-2017-
# 2           NaN          NaN
# 3  politicsNews  12-16-2016-
# 4      politics   Apr-9-2015

# %%
df['txt'] = df['title'] + " " + df['text']
df = df.drop(columns = ['title', 'text','subject','date'])
df = df.loc[~df['txt'].isna()]
df.head()
# Out:
#    label_REAL                                                txt
# 0           0  You Can Smell Hillary’s Fear Daniel Greenfield...
# 1           0  Watch The Exact Moment Paul Ryan Committed Pol...
# 2           1  Kerry to go to Paris in gesture of sympathy U....
# 3           0  Bernie supporters on Twitter erupt in anger ag...
# 4           1  The Battle of New York: Why This Primary Matte...

# %%
df.tail()
# Out:
#        label_REAL                                                txt
# 50990           1  'Fully committed' NATO backs new U.S. approach...
# 50991           1  LexisNexis withdrew two products from Chinese ...
# 50992           1  Minsk cultural hub becomes haven from authorit...
# 50993           1  Vatican upbeat on possibility of Pope Francis ...
# 50994           1  Indonesia to buy $1.14 billion worth of Russia...

# %%
#three sets: training, validation and testing sets
train_data, validate_data, test_data = np.split(df.sample(frac=1), [int(.6*len(df)), int(.8*len(df))])

train_data = train_data.reset_index(drop=True)
validate_data = validate_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

print("Size of training set: {}".format(len(train_data)))
print("Size of validation set: {}".format(len(validate_data)))
print("Size of testing set: {}".format(len(test_data)))
# Out:
# Size of training set: 30597
# Size of validation set: 10199
# Size of testing set: 10199

# %%
# !conda install -y pytorch torchvision cudatoolkit=10.1 -c pytorch
# !pip install transformers
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\lilie\anaconda3
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.1               |   py38haa95532_1         2.9 MB
#     cudatoolkit-10.1.243       |       h74a9793_0       300.3 MB
#     libuv-1.40.0               |       he774522_0         255 KB
#     ninja-1.10.2               |       h6d14046_1         250 KB
#     pytorch-1.7.1              |py3.8_cuda101_cudnn7_0       746.7 MB  pytorch
#     torchvision-0.8.2          |       py38_cu101         7.2 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        1.03 GB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        pkgs/main/win-64::cudatoolkit-10.1.243-h74a9793_0
#   libuv              pkgs/main/win-64::libuv-1.40.0-he774522_0
#   ninja              pkgs/main/win-64::ninja-1.10.2-h6d14046_1
#   pytorch            pytorch/win-64::pytorch-1.7.1-py3.8_cuda101_cudnn7_0
#   torchvision        pytorch/win-64::torchvision-0.8.2-py38_cu101
#
# The following packages will be UPDATED:
#
#   conda              conda-forge::conda-4.10.1-py38haa244f~ --> pkgs/main::conda-4.10.1-py38haa95532_1
#
#
#
# Downloading and Extracting Packages
#
# conda-4.10.1         | 2.9 MB    |            |   0%
# conda-4.10.1         | 2.9 MB    |            |   1%
# conda-4.10.1         | 2.9 MB    | #          |  10%
# conda-4.10.1         | 2.9 MB    | ##1        |  22%
# conda-4.10.1         | 2.9 MB    | ###1       |  32%
# conda-4.10.1         | 2.9 MB    | ####4      |  45%
# conda-4.10.1         | 2.9 MB    | #####5     |  55%
# conda-4.10.1         | 2.9 MB    | ######9    |  70%
# conda-4.10.1         | 2.9 MB    | ########3  |  83%
# conda-4.10.1         | 2.9 MB    | #########8 |  99%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
#
# libuv-1.40.0         | 255 KB    |            |   0%
# libuv-1.40.0         | 255 KB    | ###1       |  31%
# libuv-1.40.0         | 255 KB    | ########## | 100%
# libuv-1.40.0         | 255 KB    | ########## | 100%
#
# ninja-1.10.2         | 250 KB    |            |   0%
# ninja-1.10.2         | 250 KB    | ###8       |  38%
# ninja-1.10.2         | 250 KB    | ########## | 100%
# ninja-1.10.2         | 250 KB    | ########## | 100%
#
# torchvision-0.8.2    | 7.2 MB    |            |   0%
# torchvision-0.8.2    | 7.2 MB    |            |   0%
# torchvision-0.8.2    | 7.2 MB    |            |   1%
# torchvision-0.8.2    | 7.2 MB    | 1          |   2%
# torchvision-0.8.2    | 7.2 MB    | 2          |   2%
# torchvision-0.8.2    | 7.2 MB    | 4          |   4%
# torchvision-0.8.2    | 7.2 MB    | 8          |   9%
# torchvision-0.8.2    | 7.2 MB    | #4         |  15%
# torchvision-0.8.2    | 7.2 MB    | #9         |  20%
# torchvision-0.8.2    | 7.2 MB    | ##4        |  25%
# torchvision-0.8.2    | 7.2 MB    | ##9        |  29%
# torchvision-0.8.2    | 7.2 MB    | ###2       |  33%
# torchvision-0.8.2    | 7.2 MB    | ###6       |  36%
# torchvision-0.8.2    | 7.2 MB    | ####1      |  41%
# torchvision-0.8.2    | 7.2 MB    | ####6      |  47%
# torchvision-0.8.2    | 7.2 MB    | #####2     |  53%
# torchvision-0.8.2    | 7.2 MB    | #####7     |  58%
# torchvision-0.8.2    | 7.2 MB    | ######2    |  63%
# torchvision-0.8.2    | 7.2 MB    | ######8    |  69%
# torchvision-0.8.2    | 7.2 MB    | #######4   |  75%
# torchvision-0.8.2    | 7.2 MB    | #######9   |  80%
# torchvision-0.8.2    | 7.2 MB    | ########4  |  85%
# torchvision-0.8.2    | 7.2 MB    | #########  |  90%
# torchvision-0.8.2    | 7.2 MB    | #########6 |  97%
# torchvision-0.8.2    | 7.2 MB    | ########## | 100%
#
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   0%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  |            |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   1%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 1          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   2%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 2          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   3%
# pytorch-1.7.1        | 746.7 MB  | 3          |   4%
# pytorch-1.7.1        | 746.7 MB  | 3          |   4%
# pytorch-1.7.1        | 746.7 MB  | 3          |   4%
# pytorch-1.7.1        | 746.7 MB  | 3          |   4%
# pytorch-1.7.1        | 746.7 MB  | 3          |   4%
# pytorch-1.7.1        | 746.7 MB  | 3          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   4%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 4          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   5%
# pytorch-1.7.1        | 746.7 MB  | 5          |   6%
# pytorch-1.7.1        | 746.7 MB  | 5          |   6%
# pytorch-1.7.1        | 746.7 MB  | 5          |   6%
# pytorch-1.7.1        | 746.7 MB  | 5          |   6%
# pytorch-1.7.1        | 746.7 MB  | 5          |   6%
# pytorch-1.7.1        | 746.7 MB  | 5          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   6%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 6          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   7%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 7          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   8%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 8          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |   9%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | 9          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  10%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #          |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  11%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #1         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  12%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #2         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  13%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #3         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  14%
# pytorch-1.7.1        | 746.7 MB  | #4         |  15%
# pytorch-1.7.1        | 746.7 MB  | #4         |  15%
# pytorch-1.7.1        | 746.7 MB  | #4         |  15%
# pytorch-1.7.1        | 746.7 MB  | #4         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  15%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #5         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  16%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #6         |  17%
# pytorch-1.7.1        | 746.7 MB  | #7         |  17%
# pytorch-1.7.1        | 746.7 MB  | #7         |  17%
# pytorch-1.7.1        | 746.7 MB  | #7         |  17%
# pytorch-1.7.1        | 746.7 MB  | #7         |  17%
# pytorch-1.7.1        | 746.7 MB  | #7         |  17%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #7         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  18%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #8         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  19%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | #9         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  20%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##         |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  21%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##1        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  22%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##2        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  23%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##3        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  24%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##4        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  25%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##5        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  26%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##6        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  27%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##7        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  28%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##8        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  29%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ##9        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  30%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###        |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  31%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###1       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  32%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###2       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  33%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###3       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  34%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###4       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  35%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###5       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  36%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###6       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  37%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###7       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  38%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###8       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  39%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ###9       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  40%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####       |  41%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  41%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  41%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  41%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  41%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####1      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  42%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####2      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  43%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####3      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  44%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####4      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  45%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####5      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  46%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####6      |  47%
# pytorch-1.7.1        | 746.7 MB  | ####7      |  47%
# ...
# cudatoolkit-10.1.243 | 300.3 MB  | ######5    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######5    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######5    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  66%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######6    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  67%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  68%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  68%
# cudatoolkit-10.1.243 | 300.3 MB  | ######7    |  68%
# cudatoolkit-10.1.243 | 300.3 MB  | ######8    |  68%
# cudatoolkit-10.1.243 | 300.3 MB  | ######8    |  68%
# cudatoolkit-10.1.243 | 300.3 MB  | ######8    |  68%
# cudatoolkit-10.1.243 | 300.3 MB  | ######8    |  69%
# cudatoolkit-10.1.243 | 300.3 MB  | ######8    |  69%
# cudatoolkit-10.1.243 | 300.3 MB  | ######8    |  69%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  69%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  69%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  69%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | ######9    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  70%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######    |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  71%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######1   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  72%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######2   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  73%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######3   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  74%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######4   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  75%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######5   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  76%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######6   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  77%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######7   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  78%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######8   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  79%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | #######9   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  80%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########   |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  81%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########1  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  82%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########2  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  83%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########3  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  84%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########4  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  85%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  86%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  86%
# cudatoolkit-10.1.243 | 300.3 MB  | ########5  |  86%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  86%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  86%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  86%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########6  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  87%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########7  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  88%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########8  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  89%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | ########9  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  90%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########  |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  91%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########1 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  92%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########2 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  93%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########3 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  94%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########4 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  95%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  96%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  96%
# cudatoolkit-10.1.243 | 300.3 MB  | #########5 |  96%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  96%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  96%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  96%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########6 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########7 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########7 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########7 |  97%
# cudatoolkit-10.1.243 | 300.3 MB  | #########7 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########7 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########7 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  98%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########8 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 |  99%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 | 100%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 | 100%
# cudatoolkit-10.1.243 | 300.3 MB  | #########9 | 100%
# cudatoolkit-10.1.243 | 300.3 MB  | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting transformers
#   Downloading transformers-4.6.1-py3-none-any.whl (2.2 MB)
# Collecting huggingface-hub==0.0.8
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Requirement already satisfied: requests in c:\users\lilie\anaconda3\lib\site-packages (from transformers) (2.24.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp38-cp38-win_amd64.whl (2.0 MB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lilie\anaconda3\lib\site-packages (from transformers) (4.60.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lilie\anaconda3\lib\site-packages (from transformers) (1.19.5)
# Requirement already satisfied: packaging in c:\users\lilie\anaconda3\lib\site-packages (from transformers) (20.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lilie\anaconda3\lib\site-packages (from transformers) (2020.6.8)
# Requirement already satisfied: filelock in c:\users\lilie\anaconda3\lib\site-packages (from transformers) (3.0.12)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\lilie\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\lilie\anaconda3\lib\site-packages (from requests->transformers) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lilie\anaconda3\lib\site-packages (from requests->transformers) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\lilie\anaconda3\lib\site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: joblib in c:\users\lilie\anaconda3\lib\site-packages (from sacremoses->transformers) (0.16.0)
# Requirement already satisfied: click in c:\users\lilie\anaconda3\lib\site-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in c:\users\lilie\anaconda3\lib\site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\lilie\anaconda3\lib\site-packages (from packaging->transformers) (2.4.7)
# Installing collected packages: huggingface-hub, sacremoses, tokenizers, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.6.1

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForSequenceClassification.from_pretrained("bert-base-uncased")
model.config.num_labels = 1
# Out:
# C:\Users\lilie\anaconda3\lib\site-packages\torch\cuda\__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Freeze the pre trained parameters
for param in model.parameters():
    param.requires_grad = False

# Add three new layers at the end of the network
model.classifier = nn.Sequential(
    nn.Linear(768, 256),
    nn.ReLU(),
    nn.Linear(256, 64),
    nn.ReLU(),
    nn.Linear(64, 2),
    nn.Softmax(dim=1)
)

model = model.to(device)

# %%
criterion = nn.MSELoss().to(device)
optimizer = optim.SGD(model.classifier.parameters(), lr=0.01)

# %%
def preprocess_text(text):
    parts = []

    text_len = len(text.split(' '))
    delta = 300
    max_parts = 5
    nb_cuts = int(text_len / delta)
    nb_cuts = min(nb_cuts, max_parts)
    
    
    for i in range(nb_cuts + 1):
        text_part = ' '.join(text.split(' ')[i * delta: (i + 1) * delta])
        parts.append(tokenizer.encode(text_part, return_tensors="pt",truncation=True, max_length=500).to(device))

    return parts

# %%
print_every = 3000

total_loss = 0
all_losses = []

CUDA_LAUNCH_BLOCKING=1

model.train()

for idx, row in train_data.iterrows():
    text_parts = preprocess_text(str(row['txt']))
    label = torch.tensor([row['label_REAL']]).long().to(device)

    optimizer.zero_grad()
    
    overall_output = torch.zeros((1, 2)).float().to(device)
    for part in text_parts:
        if len(part) > 0:
            try:
                input = part.reshape(-1)[:512].reshape(1, -1)
                # print(input.shape)
                overall_output += model(input, labels=label)[1].float().to(device)
            except Exception as e:
                print(str(e))

#     overall_output /= len(text_parts)
    overall_output = F.softmax(overall_output[0], dim=-1)

    if label == 0:
        label = torch.tensor([1.0, 0.0]).float().to(device)
    elif label == 1:
        label = torch.tensor([0.0, 1.0]).float().to(device)
        
    # print(overall_output, label)

    loss = criterion(overall_output, label)
    total_loss += loss.item()
    
    loss.backward()
    optimizer.step()

    if idx % print_every == 0 and idx > 0:
        average_loss = total_loss / print_every
        print("{}/{}. Average loss: {}".format(idx, len(train_data), average_loss))
        all_losses.append(average_loss)
        total_loss = 0
# Out:
# [enforce fail at ..\c10\core\CPUAllocator.cpp:73] data. DefaultCPUAllocator: not enough memory: you tried to allocate 6429888 bytes. Buy new RAM!

# %%
torch.save(model.state_dict(), "model_after_train.pt")

plt.plot(all_losses)

# %%
#test the accuracy of the model on the test set
total = len(test_data)
number_right = 0
model.eval()
with torch.no_grad():
    for idx, row in test_data.iterrows():
        text_parts = preprocess_text(str(row['text']))
        label = torch.tensor([row['is_fake']]).float().to(device)
        
        overall_output = torch.zeros((1,2)).to(device)
        try:
            for part in text_parts:
                if len(part) > 0:
                    overall_output += model(part.reshape(1, -1))[0]
        except RuntimeError:
            print("GPU out of memory, skipping this entry.")
            continue
            
        overall_output = F.softmax(overall_output[0], dim=-1)
            
        result = overall_output.max(0)[1].float().item()
 
        if result == label.item():
            number_right += 1
            
        if idx % print_every == 0 and idx > 0:
            print("{}/{}. Current accuracy: {}".format(idx, total, number_right / idx))
            
print("Accuracy on test data: {}".format(number_right / total))

# %%
def test(text):
    text_parts = preprocess_text(text)
    overall_output = torch.zeros((1,2)).to(device)
    try:
        for part in text_parts:
            if len(part) > 0:
                overall_output += model(part.reshape(1, -1))[0]
    except RuntimeError:
        print("GPU out of memory, skipping this entry.")

    overall_output = F.softmax(overall_output[0], dim=-1)

    value, result = overall_output.max(0)

    term = "fake"
    if result.item() == 0:
        term = "real"

    print("{} at {}%".format(term, value.item() * 100))
