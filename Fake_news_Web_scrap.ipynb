# %%
import pandas as pd
import numpy as np
import requests as r
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import time

# %% [markdown]
# # Infowars steps

# %%
# get the url
url = 'https://www.infowars.com/breaking-news/'

# %%
# get the headers
headers= '''accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr
authorization: Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvYXBpLmluZm93YXJzLmNvbSIsImlhdCI6MTU5Nzg3NDUwMSwibmJmIjoxNTk3ODc0NTAxLCJleHAiOjE2Mjk0MTA1MDEsImRhdGEiOnsidXNlciI6eyJpZCI6IjEiLCJ1c2VyX3NlY3JldCI6ImdyYXBocWxfand0XzVmMWY0ZmI4YzFmYzQifX19.xuafRbV-I3Q_Bc1o92R11q-ZZtpQzeDEgBxq6hIBq7A
cache-control: no-cache
content-length: 711
content-type: application/json
origin: https://www.infowars.com
pragma: no-cache
referer: https://www.infowars.com/
sec-ch-ua: " Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'''
headers = dict([i.split(': ') for i in headers.split('\n')])

# %%
# get the response
resp= r.get(url, headers=headers)

# %%
# make a Beautifulsoup with content
soup = BeautifulSoup(resp.content)

# %%
# check the soup is beautiful
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# find the links
url_select = [i.get('href') for i in soup.select('.css-1xjmleq')]

# %%
# make a list of links
urls = ['https://www.infowars.com'+i for i in url_select]

# %%
len(urls)
# Out:
# 15

# %%
# check the link works. 
url1 = 'https://www.infowars.com/posts/peter-schiff-americans-are-worried-about-inflation/'

# %%
# make a soup from the article link
resp1= r.get(url1)
soup1=(BeautifulSoup(resp1.content))

# %%
# get the title for the article link
title = [i.text for i in soup1.select('.css-1f72nq5')]
title
# Out:
# ['Peter Schiff: Americans Are Worried About Inflation']

# %%
# get the text of the article link
text = [' '.join(i.text.split()) for i in soup1.select('.css-6lqlxw')][0]
text
# Out:
# 'If you’ve been to the grocery store, or the gas station, or the building supply store, you know we have an inflation problem. Last month’s hotter than expected CPI confirmed what we already intuitively know. But the folks over at the Federal Reserve continue to tell us there’s nothing to worry about. They insist inflation is transitory. Their reassurances notwithstanding, people are worried. Searches for the word “inflation” hit an all-time high on Google trends in May. In this clip from a recent podcast, Peter Schiff talked about the growing public worry about inflation and why the Fed’s response is bogus. According to Google Trends, searches for the word “inflation” hit the highest level since 2004 between May 9 and May 15. That’s as far back as the data goes. Google charts trends numerically and during that time period interest in “inflation” went all the way up to 100. “If you look all the way from 2004 until the end of 2020, pretty much all the searches were pretty consistent a
# ...

# %% [markdown]
# # Infowars articles df

# %%
url14 = 'https://www.infowars.com/breaking-news/'

headers= '''accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr
authorization: Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwczpcL1wvYXBpLmluZm93YXJzLmNvbSIsImlhdCI6MTU5Nzg3NDUwMSwibmJmIjoxNTk3ODc0NTAxLCJleHAiOjE2Mjk0MTA1MDEsImRhdGEiOnsidXNlciI6eyJpZCI6IjEiLCJ1c2VyX3NlY3JldCI6ImdyYXBocWxfand0XzVmMWY0ZmI4YzFmYzQifX19.xuafRbV-I3Q_Bc1o92R11q-ZZtpQzeDEgBxq6hIBq7A
cache-control: no-cache
content-length: 711
content-type: application/json
origin: https://www.infowars.com
pragma: no-cache
referer: https://www.infowars.com/
sec-ch-ua: " Not A;Brand";v="99", "Chromium";v="90", "Google Chrome";v="90"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-site
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'''
headers = dict([i.split(': ') for i in headers.split('\n')])

resp14= r.get(url14)
soup14=(BeautifulSoup(resp14.content))
url_select14 = [i.get('href') for i in soup14.select('.css-1xjmleq')]
urls14 = ['https://www.infowars.com'+i for i in url_select14]

df14 = pd.DataFrame()

for i in urls14:
    resp= r.get(i)
    soup=(BeautifulSoup(resp.content))
    
    title = [i.text for i in soup.select('.css-1f72nq5')]
    text = [' '.join(i.text.split()) for i in soup.select('.css-6lqlxw')][0]
    data = {'title':title, 'text':text}
    
    df = pd.DataFrame(data)
    df14 = df14.append(df)
    time.sleep(5)
    print(i, '....')
    df14.reset_index(drop=True, inplace=True)
    
print('done')
df14
# Out:
# https://www.infowars.com/posts/watch-fox-news-reporter-talks-to-human-smuggler-at-border/ ....
# https://www.infowars.com/posts/i-keep-forgetting-im-president-confused-biden-makes-joke-about-having-dementia/ ....
# https://www.infowars.com/posts/rep-devin-nunes-calls-for-ashli-babbits-murderer-to-be-named-14000-hours-of-capitol-security-footage-to-be-released/ ....
# https://www.infowars.com/posts/cvs-pharmacists-using-bar-codes-on-right-hand-mark-of-the-beast/ ....
# https://www.infowars.com/posts/watch-fauci-pal-daszak-admits-chinese-colleagues-developing-killer-coronaviruses/ ....
# https://www.infowars.com/posts/pregnant-woman-stabbed-by-stranger-while-walking-with-young-son/ ....
# https://www.infowars.com/posts/milan-in-the-throes-of-total-decay-as-migrants-run-rampant/ ....
# https://www.infowars.com/posts/medical-journal-describes-whiteness-as-a-parasitic-pathology-that-has-no-cure/ ....
# ...

# %%
df14.to_csv(r'.\14scrap.csv')

# %%
df1 = pd.read_csv(r'.\1scrap.csv')
df2 = pd.read_csv(r'.\2scrap.csv')
df3 = pd.read_csv(r'.\3scrap.csv')
df4 = pd.read_csv(r'.\4scrap.csv')
df5 = pd.read_csv(r'.\5scrap.csv')
df7 = pd.read_csv(r'.\7scrap.csv')
df9 = pd.read_csv(r'.\9scrap.csv')
df10 = pd.read_csv(r'.\10scrap.csv')
df11 = pd.read_csv(r'.\11scrap.csv')
df12 = pd.read_csv(r'.\12scrap.csv')
df13 = pd.read_csv(r'.\13scrap.csv')
df14 = pd.read_csv(r'.\14scrap.csv')

# %%
infowars = pd.concat([df1,df2,df3,df4,df5,df7,df9,df10,df11,df12,df13,df14], axis=0)

# %%
infowars.reset_index(drop=True, inplace=True)

# %%
infowars.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
# drop the duplicated articles. 
infowars = infowars[~(infowars.duplicated())]

# %%
infowars
# Out:
#                                                  title  \
# 0    Watch Live: New Fauci Emails Contain Damning D...
# 1    Scientist At Center Of Lab Leak Controversy Pu...
# 2    Poll: Majority Of Americans Believe COVID Came...
# 3    German Study Finds Lockdown ‘Had No Effect’ on...
# 4    50-Year-Old Mother Charged With ‘Transphobic H...
# ..                                                 ...
# 169  Watch: Fauci Pal Daszak Admits “Chinese Collea...
# 170  Pregnant Woman Stabbed by Stranger While Walki...
# 171  Milan in the ‘Throes of Total Decay’ as Migran...
# 172  Medical Journal Describes “Whiteness” as a Par...
# 173  No Need to Vaccinate People Who’ve Previously ...
#
#                                                   text
# 0    You have found the Friday edition of The Ameri...
# 1    Revered scientific journal The Lancet has crea...
# 2    Most Americans believe that the coronavirus pa...
# 3    A major new study by German scientists at Muni...
# ...

# %%
# save inforwars df.
infowars.to_csv(r'.\df_infowars.csv', index=False)

# %% [markdown]
# # Reuters - steps

# %%
# get the reuters url
reuter_url = 'https://www.reuters.com/pf/api/v3/content/fetch/articles-by-section-alias-or-id-v1?query=%7B%22id%22%3A%22%2Fworld%22%2C%22offset%22%3A30%2C%22orderby%22%3A%22last_updated_date%3Adesc%22%2C%22size%22%3A10%2C%22website%22%3A%22reuters%22%7D&d=35&_website=reuters'

# %%
# get headers for url
headers='''accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: reuters-geo={"country":"FR", "region":"-"}; cleared-onetrust-cookies=Thu, 15 Apr 2021 15:44:20 GMT; ajs_anonymous_id=%22c4874537-d5df-40f6-8b43-0b492efbb5fa%22; sophiTagses.f730=*; _sp_duid=f6bebec5-4bbb-49c0-8422-4ac2112720e8; _ga=GA1.2.1399489477.1623070101; _gid=GA1.2.585748369.1623070101; _cb_ls=1; _cb=DY8mTN6dXxbD0hrBb; _fbp=fb.1.1623070102239.1252268407; usprivacy=1---; OptanonAlertBoxClosed=2021-06-07T12:48:27.578Z; eupubconsent-v2=CPHbNfYPHbNfYAcABBENBdCgAAAAAAAAACiQAAAAAAAA.YAAAAAAAAAAA; OneTrustWPCCPAGoogleOptOut=true; fsbotchecked=true; _v__chartbeat3=BugJ03C64XQ8CXb9mI; RT="z=1&dm=reuters.com&si=adxgs8h7kop&ss=kpmm12ed&sl=1&tt=0&obo=1"; _chartbeat2=.1623070101487.1623070175418.1.CjdlteCHyOvVBFnOG7BptVrOBVm4XA.3; OptanonConsent=isIABGlobal=false&datestamp=Mon+Jun+07+2021+14%3A49%3A35+GMT%2B0200+(Central+European+Summer+Time)&version=6.10.0&hosts=&landingPath=NotLandingPage&groups=1%3A1%2C4%3A0%2C3%3A0%2C2%3A0%2CBG33%3A0%2CSTACK42%3A0&geolocation=FR%3BIDF&AwaitingReconsent=false; _gat=1; sophiTagid.f730=f6bebec5-4bbb-49c0-8422-4ac2112720e8.1623070101.1.1623072263.1623070101.b71b415e-ca02-4f12-b49d-d85147af69aa
pragma: no-cache
referer: https://www.reuters.com/world/
sec-ch-ua: " Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36'''
headers = dict([i.split(': ') for i in headers.split('\n')])

# %%
# get response
response = r.get(reuter_url, headers=headers)

# %%
# check response
response
# Out:
# <Response [200]>

# %%
# make reponse json()
data= response.json()

# %%
# check data. 
data
# Out:
# {'statusCode': 200,
#  'message': 'Success',
#  'result': {'errors': [],
#   'pagination': {'size': 10,
#    'expected_size': 10,
#    'total_size': 0,
#    'orderby': 'display_date:desc'},
#   'fetch_type': 'collection',
#   'articles': [{'id': 'ZWIZDI4RCJPXHHZ2HNVPNWOMXU',
#     'canonical_url': '/world/china/swiss-vote-become-first-european-nation-ban-synthetic-pesticides-2021-06-07/',
#     'title': 'Swiss to vote on whether to become first European nation to ban synthetic pesticides',
#     'subtitle': None,
#     'description': 'Switzerland could become the first European country to ban artificial pesticides in a June 13 referendum which backers of the initiative hope will trigger similar prohibitions elsewhere.',
#     'content_code': 'metered',
#     'updated_time': '2021-06-07T06:58:00.219Z',
#     'published_time': '2021-06-07T06:00:00Z',
#     'display_time': '2021-06-07T06:49:13Z',
#     'primary_tag': {'topic_url': '/tags/n2-mtpix/',
#      'description': 'N2:MTPIX',
# ...

# %%
# normalize part of data needed. 
reuters_json = pd.json_normalize(data['result']['articles'])

# %%
# make a list of links of articles. 
reuters_links = ['https://www.reuters.com'+i for i in reuters_json.canonical_url]
reuters_links
# Out:
# ['https://www.reuters.com/world/china/swiss-vote-become-first-european-nation-ban-synthetic-pesticides-2021-06-07/',
#  'https://www.reuters.com/world/india/indias-vaccine-inequity-worsens-countryside-languishes-2021-06-04/',
#  'https://www.reuters.com/world/uk/meghan-gives-birth-baby-girl-called-lilibet-statement-2021-06-06/',
#  'https://www.reuters.com/world/asia-pacific/taxi-hire-bangkok-cabbie-hopes-capitalise-his-covid-19-shot-2021-06-07/',
#  'https://www.reuters.com/world/india/more-than-30-dead-southern-pakistan-train-collision-police-2021-06-07/',
#  'https://www.reuters.com/world/americas/keiko-fujimori-leads-peruvian-presidential-run-off-peru-ipsos-poll-2021-06-07/',
#  'https://www.reuters.com/world/middle-east/israels-netanyahu-alleges-election-fraud-accuses-rival-duplicity-2021-06-06/',
#  'https://www.reuters.com/world/europe/pope-calls-reconciliation-healing-over-canada-school-discovery-2021-06-06/',
# ...

# %%
# check article
u = 'https://www.reuters.com/world/china/swiss-vote-become-first-european-nation-ban-synthetic-pesticides-2021-06-07/'

# %%
# make soup of article
reuter_resp= r.get(u)
reuter_soup=(BeautifulSoup(reuter_resp.content))

# %%
# get title for article
title = [i.text for i in reuter_soup.select('h1')]
# Out:
# ['Swiss to vote on whether to become first European nation to ban synthetic pesticides']

# %%
# get text for the article. 
text = [i.text for i in reuter_soup.select('.ArticleBody__content___2gQno2.paywall-article')]

# %% [markdown]
# # Reuters Articles df

# %%
reuter_url = 'https://www.reuters.com/pf/api/v3/content/fetch/articles-by-section-alias-or-id-v1?query=%7B%22id%22%3A%22%2Fworld%22%2C%22offset%22%3A30%2C%22orderby%22%3A%22last_updated_date%3Adesc%22%2C%22size%22%3A10%2C%22website%22%3A%22reuters%22%7D&d=35&_website=reuters'

headers='''accept: */*
accept-encoding: gzip, deflate, br
accept-language: fr
cache-control: no-cache
cookie: reuters-geo={"country":"FR", "region":"-"}; cleared-onetrust-cookies=Thu, 15 Apr 2021 15:44:20 GMT; ajs_anonymous_id=%22c4874537-d5df-40f6-8b43-0b492efbb5fa%22; sophiTagses.f730=*; _sp_duid=f6bebec5-4bbb-49c0-8422-4ac2112720e8; _ga=GA1.2.1399489477.1623070101; _gid=GA1.2.585748369.1623070101; _cb_ls=1; _cb=DY8mTN6dXxbD0hrBb; _fbp=fb.1.1623070102239.1252268407; usprivacy=1---; OptanonAlertBoxClosed=2021-06-07T12:48:27.578Z; eupubconsent-v2=CPHbNfYPHbNfYAcABBENBdCgAAAAAAAAACiQAAAAAAAA.YAAAAAAAAAAA; OneTrustWPCCPAGoogleOptOut=true; fsbotchecked=true; _v__chartbeat3=BugJ03C64XQ8CXb9mI; RT="z=1&dm=reuters.com&si=adxgs8h7kop&ss=kpmm12ed&sl=1&tt=0&obo=1"; _chartbeat2=.1623070101487.1623070175418.1.CjdlteCHyOvVBFnOG7BptVrOBVm4XA.3; OptanonConsent=isIABGlobal=false&datestamp=Mon+Jun+07+2021+14%3A49%3A35+GMT%2B0200+(Central+European+Summer+Time)&version=6.10.0&hosts=&landingPath=NotLandingPage&groups=1%3A1%2C4%3A0%2C3%3A0%2C2%3A0%2CBG33%3A0%2CSTACK42%3A0&geolocation=FR%3BIDF&AwaitingReconsent=false; _gat=1; sophiTagid.f730=f6bebec5-4bbb-49c0-8422-4ac2112720e8.1623070101.1.1623072263.1623070101.b71b415e-ca02-4f12-b49d-d85147af69aa
pragma: no-cache
referer: https://www.reuters.com/world/
sec-ch-ua: " Not;A Brand";v="99", "Google Chrome";v="91", "Chromium";v="91"
sec-ch-ua-mobile: ?0
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36'''
headers = dict([i.split(': ') for i in headers.split('\n')])

response = r.get(reuter_url, headers=headers)
data= response.json()
reuters_json = pd.json_normalize(data['result']['articles'])
reuters_links = ['https://www.reuters.com'+i for i in reuters_json.canonical_url]

df_reu12 = pd.DataFrame()

for i in reuters_links:
    reuter_resp= r.get(i)
    reuter_soup=(BeautifulSoup(reuter_resp.content))
    
    title = [i.text for i in reuter_soup.select('h1')]
    text = [i.text for i in reuter_soup.select('.ArticleBody__content___2gQno2.paywall-article')]
    
    data = {'title':title, 'text':text}
    
    df = pd.DataFrame(data)
    df_reu12 = df_reu12.append(df)
    time.sleep(5)
    print(i, '....')
    df_reu12.reset_index(drop=True, inplace=True)
    
print('done')
df_reu12
# Out:
# https://www.reuters.com/world/americas/sinovac-ceo-complained-about-anti-china-comments-brazil-sources-2021-06-09/ ....
# https://www.reuters.com/world/americas/canadian-reopen-border-phases-starting-with-vaccinated-citizens-source-2021-06-09/ ....
# https://www.reuters.com/world/americas/wife-drug-kingpin-el-chapo-expected-plead-guilty-federal-court-thursday-2021-06-09/ ....
# https://www.reuters.com/world/uk/uks-queen-elizabeth-gifted-rose-named-after-late-husband-philip-2021-06-09/ ....
# https://www.reuters.com/world/americas/peru-leftist-castillo-inches-nearer-win-sharply-divided-election-2021-06-09/ ....
# https://www.reuters.com/world/middle-east/iraq-releases-iran-aligned-commander-arrested-may-officials-2021-06-09/ ....
# https://www.reuters.com/world/middle-east/turkey-says-optimistic-about-erdogan-biden-meeting-nato-summit-2021-06-09/ ....
# https://www.reuters.com/world/americas/canada-will-soon-crack-down-online-hate-wake-fatal-attack-minister-2021-06-09/ ....
# ...

# %%
df_reu12.to_csv(r'.\df_reu12.csv')

# %%
rdf1 = pd.read_csv(r'.\df_reu1.csv')
rdf2 = pd.read_csv(r'.\df_reu2.csv')
rdf3 = pd.read_csv(r'.\df_reu3.csv')
rdf4 = pd.read_csv(r'.\df_reu4.csv')
rdf5 = pd.read_csv(r'.\df_reu5.csv')
rdf6 = pd.read_csv(r'.\df_reu6.csv')
rdf7 = pd.read_csv(r'.\df_reu7.csv')
rdf8 = pd.read_csv(r'.\df_reu8.csv')
rdf9 = pd.read_csv(r'.\df_reu9.csv')
rdf10 = pd.read_csv(r'.\df_reu10.csv')
rdf11 = pd.read_csv(r'.\df_reu11.csv')
rdf12 = pd.read_csv(r'.\df_reu12.csv')

# %%
# combine article dfs
reuters = pd.concat([rdf1,rdf2,rdf3,rdf4,rdf5,rdf6, rdf7, rdf8, rdf9, rdf10, rdf11, rdf12], axis=0)

# %%
reuters.reset_index(drop=True, inplace=True)

# %%
reuters.drop('Unnamed: 0', axis = 1, inplace=True)

# %%
reuters
# Out:
#                                                  title  \
# 0    Mexican rulers' lower house majority to shrink...
# 1    China administered total of 777.88 mln doses o...
# 2    Thailand starts long awaited COVID-19 vaccinat...
# 3    Afghan schoolgirl determined to return to scho...
# 4    Swiss to vote on whether to become first Europ...
# ..                                                 ...
# 115  Iraq releases Iran-aligned commander arrested ...
# 116  Turkey optimistic about Erdogan-Biden meeting ...
# 117  Canada will soon crack down on online hate in ...
# 118  Russia declares Navalny’s groups ‘extremist’ i...
# 119  Spain backtracks on nightlife rules after regi...
#
#                                                   text
# 0    Mexicans pared back President Andres Manuel Lo...
# 1    China administered about 14.8 million doses of...
# 2    Thailand kicked off a long-awaited mass vaccin...
# 3    Teenager Fatima Noori and her fellow pupils hu...
# ...

# %%
# remove any duplicate articles. 
reuters = reuters[~(reuters.duplicated())]
reuters
# Out:
#                                                  title  \
# 0    Mexican rulers' lower house majority to shrink...
# 1    China administered total of 777.88 mln doses o...
# 2    Thailand starts long awaited COVID-19 vaccinat...
# 3    Afghan schoolgirl determined to return to scho...
# 4    Swiss to vote on whether to become first Europ...
# ..                                                 ...
# 115  Iraq releases Iran-aligned commander arrested ...
# 116  Turkey optimistic about Erdogan-Biden meeting ...
# 117  Canada will soon crack down on online hate in ...
# 118  Russia declares Navalny’s groups ‘extremist’ i...
# 119  Spain backtracks on nightlife rules after regi...
#
#                                                   text
# 0    Mexicans pared back President Andres Manuel Lo...
# 1    China administered about 14.8 million doses of...
# 2    Thailand kicked off a long-awaited mass vaccin...
# 3    Teenager Fatima Noori and her fellow pupils hu...
# ...

# %%
# save reuters df.
reuters.to_csv(r'.\df_reuters.csv', index=False)
